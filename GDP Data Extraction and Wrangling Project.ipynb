You can also use this section to suppress warnings generated by your code:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

# %%
URL="https://web.archive.org/web/20230902185326/https://en.wikipedia.org/wiki/List_of_countries_by_GDP_%28nominal%29"

# %%
# Extract tables from webpage using Pandas. Retain table number 3 as the required dataframe.
tables = pd.read_html(URL)
df = tables[3]

# Replace the column headers with column numbers
df.columns = range(df.shape[1])

# Retain columns with index 0 and 2 (name of country and value of GDP quoted by IMF)
df = df[[0,2]]

# Retain the Rows with index 1 to 10, indicating the top 10 economies of the world.
df = df.iloc[1:11,:]

# Assign column names as "Country" and "GDP (Million USD)"
df.columns = ['Country','GDP (Million USD)']
print(df)
# Out:
#            Country GDP (Million USD)
# 1    United States          26854599
# 2            China          19373586
# 3            Japan           4409738
# 4          Germany           4308854
# 5            India           3736882
# 6   United Kingdom           3158938
# 7           France           2923489
# 8            Italy           2169745
# 9           Canada           2089672
# 10          Brazil           2081235

# %%
# Change the data type of the 'GDP (Million USD)' column to integer. Use astype() method.
df['GDP (Million USD)'] = df['GDP (Million USD)'].astype(int)

# Convert the GDP value in Million USD to Billion USD
df[['GDP (Million USD)']] = df[['GDP (Million USD)']]/1000

# Use numpy.round() method to round the value to 2 decimal places.
df[['GDP (Million USD)']] = np.round(df[['GDP (Million USD)']], 2)

# Rename the column header from 'GDP (Million USD)' to 'GDP (Billion USD)'
df.rename(columns = {'GDP (Million USD)' : 'GDP (Billion USD)'})
# Out:
#            Country  GDP (Billion USD)
# 1    United States           26854.60
# 2            China           19373.59
# 3            Japan            4409.74
# 4          Germany            4308.85
# 5            India            3736.88
# 6   United Kingdom            3158.94
# 7           France            2923.49
# 8            Italy            2169.74
# 9           Canada            2089.67
# 10          Brazil            2081.24

# %%
# Load the DataFrame to the CSV file named "Largest_economies.csv"


df.to_csv('./Largest_economies.csv')

# %%
import os
print(os.getcwd())             # Show you exactly where the file i loaded is located
# Out:
# C:\Users\Kwesi Oswald

# %%
a= pd.read_csv('Largest_economies.csv')
a                                           # Reads the Dataframe from where i saved it
# Out:
#    Unnamed: 0         Country  GDP (Million USD)
# 0           1   United States           26854.60
# 1           2           China           19373.59
# 2           3           Japan            4409.74
# 3           4         Germany            4308.85
# 4           5           India            3736.88
# 5           6  United Kingdom            3158.94
# 6           7          France            2923.49
# 7           8           Italy            2169.74
# 8           9          Canada            2089.67
# 9          10          Brazil            2081.24

# %%
b=pd.read_excel('Week_4.xlsx')
b
# Out:
#     Full Name                Email Product Code Customer Type  Unnamed: 4  \
# 0      User 1    user1@example.com       C907-P     Returning         NaN
# 1      User 2    user2@example.com       V694-B     Returning         NaN
# 2      User 3    user3@example.com       T732-C           New         NaN
# 3      User 4    user4@example.com       K184-B           New         NaN
# 4      User 5    user5@example.com       U713-G     Returning         NaN
# ..        ...                  ...          ...           ...         ...
# 195  User 196  user196@example.com       V647-J           New         NaN
# 196  User 197  user197@example.com       Y823-Q           New         NaN
# 197  User 198  user198@example.com       J973-B     Returning         NaN
# 198  User 199  user199@example.com       S869-D           New         NaN
# 199  User 200  user200@example.com       A847-B           New         NaN
#
#                                           Instructions  Unnamed: 6 Left Right  \
# 0    1. Extract first 3 characters from the rigbt a...         NaN  C90   7-P
# 1    2. Find the length of the characters in the fu...         NaN  V69   4-B
# 2                                                  NaN         NaN  T73   2-C
# 3                                                  NaN         NaN  K18   4-B
# 4                                                  NaN         NaN  U71   3-G
# ..                                                 ...         ...  ...   ...
# 195                                                NaN         NaN  V64   7-J
# 196                                                NaN         NaN  Y82   3-Q
# 197                                                NaN         NaN  J97   3-B
# 198                                                NaN         NaN  S86   9-D
# 199                                                NaN         NaN  A84   7-B
#
#      Len
# 0      6
# 1      6
# 2      6
# 3      6
# 4      6
# ..   ...
# 195    8
# 196    8
# 197    8
# 198    8
# 199    8
#
# [200 rows x 10 columns]
